# %%
# Installing the required connections
# !pip install pandas sqlalchemy mysql-connector-python

# %%
# Importing libraries and load dataset
import pandas as pd

# Load the CSV
df = pd.read_csv(r"C:\Users\Rahul R\Downloads\Cars.csv")

# Preview the dataset
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
# Perform EDA
print(df.describe())
print(df.info())
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# ...

# %%
# Handle missing values
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Rahul R\AppData\Local\Temp\ipykernel_9916\2650217428.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
# Encode categorical variables
label_encoders = {}
categorical_columns = df.select_dtypes(include=['object']).columns

for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
print(df.columns)
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

X = df.drop('MPG', axis=1) 
y = df['MPG']               

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# Initialize and train the Random Forest Regressor
model = RandomForestRegressor(n_estimators=100, random_state=5)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=5)

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 0.13059290264190584
# R² Score: 0.7020789968606764

# %%
#RandomForestRegressor model demonstrates solid performance.low MSE indicates that the average squared difference between your model's
#predictions and the actual values is minimal, signifying high predictive accuracy

# %%
#An R² value of 0.7021 means that approximately 70.21% of the variance in the target variable. to improve this value we can hyper parameter tuning.

# %%
import pickle

# Save trained model
with open('rf_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Save the feature names in the same order used during training
feature_names = X.columns.tolist()  # X is your training feature DataFrame
with open('features.pkl', 'wb') as f:
    pickle.dump(feature_names, f)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Rahul R
